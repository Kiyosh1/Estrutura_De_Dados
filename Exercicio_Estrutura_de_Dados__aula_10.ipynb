# %% [markdown]
# #Exercicios - Aula 10

# %% [markdown]
# ### Exercício 1: Usando a `UnsortedPriorityQueue` no Google Colab
#
# Neste exercício, vamos criar uma fila de prioridade não ordenada e realizar várias operações para entender seu funcionamento. Siga os passos abaixo:
#
# #### Passo 1: Crie uma fila de prioridade
#
# ```python
# # Crie uma instância de UnsortedPriorityQueue
# ```
#
# Adicione os seguintes elementos à fila de prioridade
#
# # Adicionando elementos à fila de prioridade
# pq.add(15, 'A')
#
# pq.add(20, 'B')
#
# pq.add(10, 'C')
#
# pq.add(30, 'D')
#
# pq.add(25, 'E')
#
# pq.add(5, 'F')
#
# pq.add(35, 'G')
#
# pq.add(40, 'H')
#
# pq.add(1, 'I')
#
# pq.add(50, 'J')
#
# Verifique se a fila está vazia
#
# Obtenha o número de elementos na fila de prioridade
#
# Imprima o elemento com a menor chave
#
# Remova e imprima o elemento com a menor chave
#
# Verifique a prioridade de todos os elementos na fila

# %%
#Codigo aqui

# %% [markdown]
# ### Exercício: Usando a `SortedPriorityQueue` no Google Colab
#
# Neste exercício, vamos criar uma fila de prioridade ordenada e realizar várias operações para entender seu funcionamento. Siga os passos abaixo:
#
# #### Passo 1: Crie uma fila de prioridade
#
# ```python
# # Crie uma instância de SortedPriorityQueue
# ```
#
# Adicione os seguintes elementos à fila de prioridade
#
# pq.add(15, 'A')
#
# pq.add(20, 'B')
#
# pq.add(10, 'C')
#
# pq.add(30, 'D')
#
# pq.add(25, 'E')
#
# pq.add(5, 'F')
#
# pq.add(35, 'G')
#
# pq.add(40, 'H')
#
# pq.add(1, 'I')
#
# pq.add(50, 'J')
#
# Verifique se a fila está vazia
#
# Obtenha o número de elementos na fila de prioridade
#
#  Imprima o elemento com a menor chave
#
#  Remova e imprima o elemento com a menor chave
#
#  Verifique a prioridade de todos os elementos na fila

# %% [markdown]
# Quais as semelhanças e as diferenças de tempo de execução das operações no pior caso da lista ordenada e desordenada em Fila de Prioridade?
#
# Resposta:
