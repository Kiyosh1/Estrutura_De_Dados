# %% [markdown]
# #### Fazer apenas em Python

# %% [markdown]
# # Exercício 1: Inserção e Remoção Simples
#
# Crie uma fila de prioridade vazia e adicione três pares chave-valor à fila. Em seguida, remova o item com a menor chave e imprima o estado da fila de prioridade após cada operação.
#
# ### Passos sugeridos:
# 1. Crie uma instância da `HeapPriorityQueue`.
# 2. Use o método `add()` para adicionar os seguintes pares `(3, "C")`, `(1, "A")`, e `(2, "B")`.
# 3. Remova o item com a menor chave usando o método `remove_min()` e imprima o estado da fila após a remoção.
#
# ---
#
# # Exercício 2: Verificação da Ordem de Mínimos
#
# Adicione uma série de pares chave-valor à fila de prioridade e, sem removê-los, verifique se o método `min()` sempre retorna o item com a menor chave.
#
# ### Passos sugeridos:
# 1. Adicione os pares `(10, "Z")`, `(5, "Y")`, `(1, "X")`, `(7, "W")`, `(3, "V")`.
# 2. Use o método `min()` várias vezes e verifique se ele retorna o item correto sem removê-lo.
#
# ---
#
# # Exercício 3: Heap com Dados Reais
#
# Implemente um sistema de fila de prioridade para tarefas. Cada tarefa possui uma prioridade (número inteiro) e uma descrição (string). Adicione cinco tarefas diferentes com diferentes prioridades e remova as três de maior prioridade.
#
# ### Passos sugeridos:
# 1. Adicione cinco tarefas, por exemplo: `(2, "Tarefa 1")`, `(5, "Tarefa 2")`, `(1, "Tarefa 3")`, `(4, "Tarefa 4")`, `(3, "Tarefa 5")`.
# 2. Remova três tarefas usando o método `remove_min()`

# %%
#copie e cole o codigo HeapPriorityQueue() aqui
