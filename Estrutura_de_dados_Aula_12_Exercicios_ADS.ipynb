# %% [markdown]
# # 🌳 Exercícios: Testando a Implementação da Classe `TreeMap` (Todos em python)
#
# ## 📌 Contexto
#
# Utilize a classe `TreeMap` implementada com árvore binária de busca para resolver os seguintes exercícios. O objetivo é testar as operações de inserção, consulta, atualização, exclusão e busca por intervalos na árvore.
#
# ---
#
# ## 🚀 Exercício 1 – Inserção e Consulta de Valores
#
# 1️⃣ Crie um `TreeMap` e insira os seguintes pares **chave-valor**:
#
# | Chave | Valor  |
# |:----:|:-------|
# | 50   | "A"    |
# | 30   | "B"    |
# | 70   | "C"    |
# | 20   | "D"    |
# | 40   | "E"    |
# | 60   | "F"    |
# | 80   | "G"    |
#
# 2️⃣ Consulte e exiba os valores associados às seguintes chaves:
# - `map[50]`
# - `map[20]`
# - `map[70]`
#
# ### 🎯 Resultado esperado
#
# ```python
# map[50] -> "A"
# map[20] -> "D"
# map[70] -> "C"

# %% [markdown]
# ## ✏️ Exercício 2 – Atualização e Exclusão de Elementos
#
# 1️⃣ Atualize o valor associado à chave `30` para `"Z"`.
# 2️⃣ Exclua a chave `70` do `TreeMap`.
# 3️⃣ Liste todas as chaves e valores restantes em **ordem crescente de chave**.
#
# ---
#
# ### 🎯 Resultado esperado
#
# | Chave | Valor  |
# |:----:|:-------|
# | 20   | "D"    |
# | 30   | "Z"    |
# | 40   | "E"    |
# | 50   | "A"    |
# | 60   | "F"    |
# | 80   | "G"    |

# %% [markdown]
# ## 🔍 Exercício 3 – Busca por Intervalos e Mínimos
#
# 1️⃣ Obtenha o menor par (chave, valor) usando o método `find_min()`.
# 2️⃣ Liste todos os pares no intervalo `[30, 70)` utilizando o método `find_range(30, 70)`.
#
# ---
#
# ### 🎯 Resultado esperado
#
# ```python
# find_min() -> (20, "D")
#
# find_range(30, 70) -> [
#     (30, "Z"),
#     (40, "E"),
#     (50, "A"),
#     (60, "F")
# ]
