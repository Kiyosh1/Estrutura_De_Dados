# %% [markdown]
# #Exercício - Aula 13

# %%
# numpy: Biblioteca para computação científica em Python, com suporte para arrays e operações matemáticas de alto desempenho.
import numpy as np

# matplotlib.pyplot: Biblioteca para visualização de dados, especial para gráficos e plotagens.
import matplotlib.pyplot as plt

# Analise de Tabelas
import pandas as pd

# medida de tempo
import time

# %% [markdown]
# 1. Copie e cole o algoritmo  `merge_sort_column(df, column_name)`
#
# 2. Utilize o gerador de números aleatórias que cria um dataFrame de  size=1000. (O código já esta feito)
#
# 3. Execute o código para calcular o tempo de execução do `merge_sort_column(df, column_name)` para ordenar os números do DataFrame para size=1000 e depois faça para size=2000.
#
# 4. Quanto tempo foi preciso para ordenar os números do dataframe com size=1000 e com size=2000. Quantas vezes é a diferença de tempo de execução entre um e outro?
#
# Resposta:
#
# Repita do item 1 até o 4 mas dessa vez utilizando o algoritmo `quick_sort_column(df, column_name)`
#
# 5. Ao final de todos os experimentos responda:
#
# 6. Qual foi o algoritmo mais rápido para ordenar  com size=1000?
#
# Resposta:
#
# 7. Qual foi o algoritmo mais rápido para ordenar  com size=2000?
#
# Resposta:
#
# Obs: utilize o time para medir o tempo.

# %%
#Copie e cole o codigo aqui

# %%
# Gerando 1000 números aleatórios entre 0 e 10000
random_numbers = np.random.randint(0, 10000, size=1000)

# Criando o DataFrame
df = pd.DataFrame(random_numbers, columns=["Numeros_Aleatorios"])

print(df)
# Out:
#      Numeros_Aleatorios
# 0                   753
# 1                  5017
# 2                  3720
# 3                  2918
# 4                  1042
# ..                  ...
# 995                1339
# 996                9239
# 997                 113
# 998                3796
# 999                1064
#
# [1000 rows x 1 columns]

# %%
# Medindo o tempo de execução da função
start_time = time.time()
df_sorted = merge_sort_column(df,#continue.....
end_time = time.time()
execution_time = end_time - start_time

# Exibindo o tempo de execução
print(f"Tempo de execução: {execution_time:.6f} segundos")
